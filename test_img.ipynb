# %%
import nrrd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# fname = '/store1/shared/panneuralGFP_new/data_processed/2025-03-15-15_output/NRRD/2025-03-15-15_t1282_ch2.nrrd'
fname = '/store1/shared/panneuralGFP_new/data_processed/2025-03-15-15_output/neuropal/2025-03-15-16/NRRD/2025-03-15-16_t0032_ch2.nrrd'
data, header = nrrd.read(fname)

# %%
data
# Out:
# array([[[102, 111,  78, ..., 125,  55,  42],
#         [105, 135, 110, ..., 155,  50,  29],
#         [130, 118, 112, ..., 148,  19,  31],
#         ...,
#         [ 38,  30,  37, ...,  67,  62,   0],
#         [ 93, 100,  36, ..., 133,  71,  24],
#         [ 81,  66, 109, ..., 112,  77,  18]],
#
#        [[ 98,  75,  91, ..., 154,  34,  49],
#         [ 75, 130,  58, ..., 126,  18,   8],
#         [ 72, 113,  84, ..., 120,  56,  25],
#         ...,
#         [ 81,  76,  78, ...,  76,  16,   0],
#         [104,  46,  47, ...,  61,  66,  55],
#         [ 83,  44, 111, ..., 113,  99,  24]],
#
#        [[ 87, 110,  85, ..., 100,  21,  24],
#         [ 95, 156, 100, ..., 133,  41,  29],
#         [102, 112, 154, ...,  93,  24,   2],
#         ...,
#         [ 45,  67,  71, ..., 106,  38,  17],
#         [ 67, 106, 115, ..., 125,  12,  41],
#         [101,  91, 125, ...,  82,  63,  32]],
#
#        ...,
#
#        [[ 51,  93,  96, ...,  93,   0,  34],
# ...

# %%
plt.imshow(np.max(data, axis=2))
